# %%
# import Frequentist class 
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
from pyab.experiments import ABTestFrequentist, ABTestBayesian
# Out:
# /anaconda3/lib/python3.7/site-packages/statsmodels/compat/pandas.py:49: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)

# %%
# provide significance rate and type of test
ad_experiment = ABTestFrequentist(alpha=0.05, alt_hypothesis='one_tailed')

# conduct experiment with two variants successes and trials, returns stat & pvalue
stat, pvalue = ad_experiment.conduct_experiment(success_null=100, trials_null=1000, 
                                 success_alt=125, trials_alt=1000)
# Out:
# pyAB Summary
# ============
#
# Test Parameters
# _______________
#
# Variant A: Success Rate 0.1, Sample Size 1000
# Variant B: Success Rate 0.125, Sample Size 1000
# Type-I Error: 0.05, one_tailed test
#
# Test Results
# ____________
#
# There is a statistically significant difference in proportions of two variants
#
# Test Stat: 1.769
# p-value: 0.038
# Type-II Error: 0.451
# Power: 0.549

# %%
a = ABTestBayesian(success_prior=10, trials_prior=100)
a.conduct_experiment(100, 1000, 125, 1000, uplift_method='uplift_percent', n_trials=1000)
# Out:
# pyAB Summary
# ============
#
# Test Parameters
# _______________
#
# Variant A: Successful Trials 100, Sample Size 1000
# Variant B: Successful Trials 125, Sample Size 1000
# Prior: Successful Trials 10, Sample Size 100
#
# Test Results
# ____________
#
# Evaluation Metric: uplift_percent
#
# Samples per group for mcmc simulation: 1000
# 99.15 % simulations show Uplift Gain Percent above 0.
